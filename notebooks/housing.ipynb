# %%
# !pip3 install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 2.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 2.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 1.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 3.7 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
melbourne_data = pd.read_csv("../datasets/melb_data.csv")
melbourne_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
import datetime
melbourne_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 3  4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 4  4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN       Yarra   -37.7996    144.9984
# ...

# %%
# Average land size rounded
avg_land_size = round(melbourne_data["Landsize"].mean())

# As of today, how old is the newest home (current year - the date in which it was built)
newest_home_age = datetime.datetime.now().year - melbourne_data["YearBuilt"].max()

avg_land_size, newest_home_age
# Out:
# (558, 6.0)

# %%
melbourne_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# Drop lines with missing column values
melbourne_data = melbourne_data.dropna(axis=0)

# %%
# Prediction target is the price
y = melbourne_data.Price

# Features selected by intuition
melbourne_features = ["Rooms", "Bathroom", "Landsize", "Lattitude", "Longtitude"]
X = melbourne_data[melbourne_features]

# %%
X.describe()
# Out:
#              Rooms     Bathroom      Landsize    Lattitude   Longtitude
# count  6196.000000  6196.000000   6196.000000  6196.000000  6196.000000
# mean      2.931407     1.576340    471.006940   -37.807904   144.990201
# std       0.971079     0.711362    897.449881     0.075850     0.099165
# min       1.000000     1.000000      0.000000   -38.164920   144.542370
# 25%       2.000000     1.000000    152.000000   -37.855438   144.926198
# 50%       3.000000     1.000000    373.000000   -37.802250   144.995800
# 75%       4.000000     2.000000    628.000000   -37.758200   145.052700
# max       8.000000     8.000000  37000.000000   -37.457090   145.526350

# %%
X.head()
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 4      4       1.0     120.0   -37.8072    144.9941
# 6      3       2.0     245.0   -37.8024    144.9993
# 7      2       1.0     256.0   -37.8060    144.9954

# %%
# !pip3 install scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 403.1 kB/s eta 0:00:00:--:--
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 16.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 2.2 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
from sklearn.tree import DecisionTreeRegressor

melbourne_model = DecisionTreeRegressor(random_state=2024)

melbourne_model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=2024)

# %%
X.head()
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 4      4       1.0     120.0   -37.8072    144.9941
# 6      3       2.0     245.0   -37.8024    144.9993
# 7      2       1.0     256.0   -37.8060    144.9954

# %%
predicted_pricing = melbourne_model.predict(X.head())
predicted_pricing
# Out:
# array([1035000., 1465000., 1600000., 1876000., 1636000.])

# %%
X_head_predictions = X.head().copy()
X_head_predictions["PredictedPricing"] = predicted_pricing

X_head_predictions
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude  PredictedPricing
# 1      2       1.0     156.0   -37.8079    144.9934         1035000.0
# 2      3       2.0     134.0   -37.8093    144.9944         1465000.0
# 4      4       1.0     120.0   -37.8072    144.9941         1600000.0
# 6      3       2.0     245.0   -37.8024    144.9993         1876000.0
# 7      2       1.0     256.0   -37.8060    144.9954         1636000.0

# %%
melbourne_data.head()
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 4  Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 6  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 1  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 4  4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
# 6  7/05/2016       2.5    3067.0       4.0       2.0  0.0     245.0
# 7  8/10/2016       2.5    3067.0       2.0       1.0  2.0     256.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 1          79.0     1900.0       Yarra   -37.8079    144.9934
# ...

# %%
# Model validation

from sklearn.metrics import mean_absolute_error

predicted_home_prices = melbourne_model.predict(X)
mean_absolute_error(y, predicted_home_prices)
# Out:
# 1115.7467183128902

# %%
from sklearn.model_selection import train_test_split

# Splitting data to training data and validation data
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=0)

melbourne_model = DecisionTreeRegressor(random_state=1)
melbourne_model.fit(train_X, train_y)

predicted_y = melbourne_model.predict(val_X)
mean_absolute_error(val_y, predicted_y)
# Out:
# 273518.01872175594

# %% [markdown]
# # This model is horrible in practice
# Looking at the difference between the in-sample MAE and the out-of-sample MAE, we can clearly see that this model is extremely inefficient in real world applications

# %%
# Trying different max leaves values

def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes,
                                  random_state=0)
    model.fit(train_X, train_y)
    predicted_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, predicted_val)
    return mae

# %%
mae_arr = []
max_leaf_nodes = 5

while(max_leaf_nodes <= 5000):
    mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    mae_arr.append(mae)
    max_leaf_nodes *= 2

mae_arr
# Out:
# [385696.54278937966,
#  333908.4783704852,
#  311113.0621330481,
#  291120.560654963,
#  274836.33554513264,
#  267987.0227469099,
#  264976.3494609528,
#  260819.31064998003,
#  264264.8835303582,
#  271251.72465043026]

# %%
# !pip3 install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.1/159.1 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 8.7 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.2/258.2 kB 469.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 4.7 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 3.7 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 3.4 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

plt.plot(mae_arr, marker='o', linestyle='-')

plt.xlabel("Max leaf nodes")
plt.ylabel("Mean Absolute Error")
plt.title("MAE vs. Max Leaf Nodes")

plt.grid(True)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(random_state=1)

rf_model.fit(train_X, train_y)

predicted_y = rf_model.predict(val_X)

rf_val_mae = mean_absolute_error(val_y, predicted_y)
rf_val_mae
# Out:
# 207190.6873773146
